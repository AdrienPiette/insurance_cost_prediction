# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
data = pd.read_csv(r'C:\Users\pieta\OneDrive\Bureau\insurance_prediction\insurance_cost_prediction\data\insurance.csv')

# %%
data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
for i in data:
    if data[i].dtype == 'object':
        print(i, data[i].unique())
# Out:
# sex ['female' 'male']
# smoker ['yes' 'no']
# region ['southwest' 'southeast' 'northwest' 'northeast']

# %%
# plot age distribution by sex

fig = px.histogram(data, x='charges', color='sex', barmode='overlay', title='Age by Sex Distribution')
fig.show()

# %%
fig = px.histogram(data, x='charges', color='smoker', barmode='overlay', title='Charges by Smoker Distribution')
fig.show()

# %%
fig = px.histogram(data, x='charges', color='region', barmode='overlay', title='Charges by Region Distribution')
fig.show()

# %%
fig = px.histogram(data, x='charges', color='children', barmode='overlay', title='Charges by Children Distribution')
fig.show()

# %%
fig = px.histogram(data, x='charges', color = 'bmi', barmode='overlay', title='Charges by BMI Distribution')
fig.show()
